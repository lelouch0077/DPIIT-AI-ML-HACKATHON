# %%
import json
import pytesseract
# !apt-get update
# !apt-get install tesseract-ocr-hin tesseract-ocr-ara

from PIL import Image
# !pip install langdetect

from langdetect import detect
image_path = "/kaggle/input/checktext/input_image.png"       
layout_json_path = "/kaggle/input/checktext/layout.json"      
output_json_path = "final_output.json"

image = Image.open(image_path)

with open(layout_json_path, "r", encoding="utf-8") as f:
    layout_data = json.load(f)

output_data = []

for block in layout_data:
    bbox = block.get("bbox")
    block_type = block.get("type", "Text")

    if not bbox or len(bbox) != 4:
        continue  # skip invalid bbox

    x1, y1, x2, y2 = map(int, bbox)#get image crop cordinates
    cropped = image.crop((x1, y1, x2, y2))

    # Run OCR
    text = pytesseract.image_to_string(cropped, lang='eng+hin+ara')
    lang = detect(text) if text else "unknown"#detect language
    print(text)

    output_data.append({
        "bbox": bbox,
        "type": block_type,
        "text": text,
        "language": lang
    })

with open(output_json_path, "w", encoding="utf-8") as f:
    json.dump(output_data, f, ensure_ascii=False, indent=2)

print("Output saved to:", output_json_path)
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,804 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [79.8 kB]
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease [24.6 kB]
# Get:13 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,078 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,092 kB]
# Get:15 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [33.2 kB]
# Get:16 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,752 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [56.4 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,404 kB]
# Get:19 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [51.0 kB]
# Get:20 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [48.5 kB]
# Get:21 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,262 kB]
# Get:22 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [4,763 kB]
# Get:23 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 Packages [75.1 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,566 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [4,917 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.2 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [83.2 kB]
# Fetched 33.6 MB in 3s (10.6 MB/s)
#
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
#
#
#
# The following NEW packages will be installed:
#   tesseract-ocr-ara tesseract-ocr-hin
# 0 upgraded, 2 newly installed, 0 to remove and 202 not upgraded.
# Need to get 1,557 kB of archives.
# After this operation, 2,585 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-ara all 1:4.00~git30-7274cfa-1.1 [645 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-hin all 1:4.00~git30-7274cfa-1.1 [913 kB]
# Fetched 1,557 kB in 0s (6,119 kB/s)
# Selecting previously unselected package tesseract-ocr-ara.
# (Reading database ... 129184 files and directories currently installed.)
# Preparing to unpack .../tesseract-ocr-ara_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-ara (1:4.00~git30-7274cfa-1.1) ...
# Selecting previously unselected package tesseract-ocr-hin.
# Preparing to unpack .../tesseract-ocr-hin_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-hin (1:4.00~git30-7274cfa-1.1) ...
# Setting up tesseract-ocr-ara (1:4.00~git30-7274cfa-1.1) ...
# Setting up tesseract-ocr-hin (1:4.00~git30-7274cfa-1.1) ...
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 13.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from langdetect) (1.17.0)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993223 sha256=45c0cc669754e112b66ee6a65659fcb336d233bbc421c049101ad8bc38b73fa6
#   Stored in directory: /root/.cache/pip/wheels/0a/f2/b2/e5ca405801e05eb7c8ed5b3b4bcf1fcabcd6272c167640072e
# Successfully built langdetect
# Installing collected packages: langdetect
# Successfully installed langdetect-1.0.9
# API Abdul Kalam, often referred to as the "People's President," was an Indian scientist and statesman
# who served as the 11th President of India from 2002 to 2007. Born into a poor family in
# Rameswaram, Tamil Nadu, he rose to become a key figure in India's space and defense programs,
# earning him the moniker "Missile Man of India". Beyond his scientific achievements, Kalam was a
#
# passionate advocate for education, particularly inspiring youth to pursue their dreams and contribute
# to national development.
#
#
#
# एपीजे अब्दुल कलाम, जिन्हें अक्सर "लोगों के राष्ट्रपति" के रूप में जाना जाता है, एक भारतीय वैज्ञानिक और राजनेता थे,
# जिन्होंने 2002 से 2007 तक भारत के 11वें राष्ट्रपति के रूप में कार्य किया। तमिलनाडु के रामेश्वरम में एक गरीब परिवार
# में जन्मे, वे भारत के अंतरिक्ष और रक्षा कार्यक्रमों में एक प्रमुख व्यक्ति बन गए, जिससे उन्हें "भारत का मिसाइल मैन"
#
# उपनाम मिला। अपनी वैज्ञानिक उपलब्धियों से परे, कलाम शिक्षा के लिए एक भावुक वकील थे, विशेष रूप से युवाओं को
# अपने सपनों को पूरा करने और राष्ट्रीय विकास में योगदान देने के लिए प्रेरित करते थे।
#
# أبو بكر زين العايدين عبد الكلام» المعروف غالتا ب"رئيس الشعب"٠‏ كان عالمًا ويجل دولة هندنا شغل منصي الرئيس الجادي
# لهند من عام 2002 إلى عام 2007. وُلِدٍ لعائلة فقيرة في رامسوارام» ‎carl lal‏ وبرز ليصيج شخصية بارزاً في يرامج الفضاء
# “والدفاع الهندمة» مما أكسيه لقب "رجل الصواريخ المندكي”. إلى جانس إنجاناته العلمية» كاير عبد الكلام مناصرا متحمس للتعليم
# إلاسيما الهامه للشباب لتجقيق أجلامهم والمساهمة فى التنمية الوطنية
#
# Output saved to: final_output.json
